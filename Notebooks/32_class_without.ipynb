# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression, Perceptron
from sklearn.preprocessing import StandardScaler, LabelEncoder

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %%
def plot_confusion(cm, classes, title):
    plt.figure(figsize=(16, 14))  # 👈 wider plot
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=classes, yticklabels=classes)
    plt.title(f'Confusion Matrix - {title}')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.xticks(rotation=90)  # 👈 avoid overlapping
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

def evaluate_model(y_true, y_pred, class_labels, title):
    print(f"\n📌 Results for {title}")
    print(classification_report(y_true, y_pred, target_names=class_labels))
    cm = confusion_matrix(y_true, y_pred)
    plot_confusion(cm, class_labels, title)

# %%
# Load the 34-class reduced dataset
import glob

# Load and combine the 4 parts from the 34-class full dataset
file_paths = sorted(glob.glob("/content/drive/MyDrive/CICIoT2023/34class/*.parquet"))
df = pd.concat([pd.read_parquet(fp) for fp in file_paths], ignore_index=True)

# Separate features and label
X = df.drop('label', axis=1)
y = df['label']

# Encode labels
le = LabelEncoder()
y_enc = le.fit_transform(y)
class_names = le.classes_

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split (80-20)
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_enc, test_size=0.2, stratify=y_enc, random_state=42
)

# %%
start = time.time()
rf = RandomForestClassifier(n_estimators=100, max_depth=None, n_jobs=-1, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
end = time.time()

print(f"🕒 Random Forest time: {end - start:.2f} seconds")
evaluate_model(y_test, y_pred_rf, class_names, "Random Forest (34-class)")
# Out:
# 🕒 Random Forest time: 337.27 seconds
#
# 📌 Results for Random Forest (34-class)
#                          precision    recall  f1-score   support
#
#        Backdoor_Malware       0.97      0.99      0.98     16456
#           BenignTraffic       0.86      0.89      0.87     16900
#        BrowserHijacking       0.95      0.99      0.97     16456
#        CommandInjection       0.96      0.98      0.97     16456
#  DDoS-ACK_Fragmentation       1.00      1.00      1.00     16900
#         DDoS-HTTP_Flood       1.00      1.00      1.00     16456
#         DDoS-ICMP_Flood       1.00      1.00      1.00     16900
# DDoS-ICMP_Fragmentation       1.00      1.00      1.00     16900
#       DDoS-PSHACK_Flood       1.00      1.00      1.00     16900
#        DDoS-RSTFINFlood       1.00      1.00      1.00     16900
#          DDoS-SYN_Flood       1.00      1.00      1.00     16900
#          DDoS-SlowLoris       1.00      1.00      1.00     16456
# DDoS-SynonymousIP_Flood       1.00      1.00      1.00     16900
#          DDoS-TCP_Flood       1.00      1.00      1.00     16900
#          DDoS-UDP_Flood       1.00      1.00      1.00     16900
#  DDoS-UDP_Fragmentation       1.00      1.00      1.00     16900
#            DNS_Spoofing       0.91      0.85      0.88     16900
#    DictionaryBruteForce       0.92      0.97      0.94     16456
#          DoS-HTTP_Flood       1.00      1.00      1.00     16456
#           DoS-SYN_Flood       1.00      1.00      1.00     16900
#           DoS-TCP_Flood       1.00      1.00      1.00     16900
#           DoS-UDP_Flood       1.00      1.00      1.00     16900
#        MITM-ArpSpoofing       0.95      0.86      0.90     16900
#      Mirai-greeth_flood       1.00      1.00      1.00     16900
#       Mirai-greip_flood       1.00      1.00      1.00     16900
#          Mirai-udpplain       1.00      1.00      1.00     16900
#     Recon-HostDiscovery       0.92      0.92      0.92     16900
#            Recon-OSScan       0.87      0.85      0.86     16900
#         Recon-PingSweep       0.97      1.00      0.98     16456
#          Recon-PortScan       0.87      0.77      0.82     16456
#            SqlInjection       0.94      0.99      0.97     16456
#        Uploading_Attack       0.98      1.00      0.99     16456
#       VulnerabilityScan       1.00      1.00      1.00     16456
#                     XSS       0.96      0.99      0.97     16456
#
#                accuracy                           0.97    568828
#               macro avg       0.97      0.97      0.97    568828
#            weighted avg       0.97      0.97      0.97    568828

# %%
lr = LogisticRegression(
    multi_class='multinomial',
    solver='saga',
    max_iter=300,          # Reduced from 1000
    tol=1e-2,              # Loosen convergence
    n_jobs=-1,             # All CPU cores
    verbose=1              # Show iteration progress
)

start = time.time()
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)
end = time.time()

print(f"🕒 Logistic Regression time: {end - start:.2f} seconds")
evaluate_model(y_test, y_pred_lr, class_names, "Logistic Regression (34-class)")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# convergence after 40 epochs took 517 seconds
# 🕒 Logistic Regression time: 517.50 seconds
#
# 📌 Results for Logistic Regression (34-class)
#                          precision    recall  f1-score   support
#
#        Backdoor_Malware       0.18      0.10      0.13     16456
#           BenignTraffic       0.34      0.47      0.40     16900
#        BrowserHijacking       0.24      0.13      0.17     16456
#        CommandInjection       0.68      0.17      0.27     16456
#  DDoS-ACK_Fragmentation       0.76      0.96      0.85     16900
#         DDoS-HTTP_Flood       0.52      0.72      0.60     16456
#         DDoS-ICMP_Flood       1.00      1.00      1.00     16900
# DDoS-ICMP_Fragmentation       1.00      0.97      0.99     16900
#       DDoS-PSHACK_Flood       0.85      0.98      0.91     16900
#        DDoS-RSTFINFlood       0.99      1.00      0.99     16900
#          DDoS-SYN_Flood       0.45      0.95      0.61     16900
#          DDoS-SlowLoris       0.32      0.31      0.32     16456
# DDoS-SynonymousIP_Flood       0.59      0.65      0.62     16900
#          DDoS-TCP_Flood       0.50      0.97      0.66     16900
#          DDoS-UDP_Flood       0.55      0.99      0.71     16900
#  DDoS-UDP_Fragmentation       0.83      0.98      0.90     16900
#            DNS_Spoofing       0.25      0.27      0.26     16900
#    DictionaryBruteForce       0.71      0.17      0.27     16456
#          DoS-HTTP_Flood       0.69      0.70      0.70     16456
#           DoS-SYN_Flood       0.30      0.05      0.08     16900
#           DoS-TCP_Flood       0.38      0.07      0.12     16900
#           DoS-UDP_Flood       0.36      0.24      0.29     16900
#        MITM-ArpSpoofing       0.66      0.42      0.51     16900
#      Mirai-greeth_flood       0.53      0.76      0.63     16900
#       Mirai-greip_flood       0.58      0.32      0.41     16900
#          Mirai-udpplain       0.87      0.99      0.93     16900
#     Recon-HostDiscovery       0.52      0.50      0.51     16900
#            Recon-OSScan       0.19      0.03      0.05     16900
#         Recon-PingSweep       0.26      0.35      0.30     16456
#          Recon-PortScan       0.23      0.04      0.06     16456
#            SqlInjection       0.19      0.17      0.18     16456
#        Uploading_Attack       0.19      0.39      0.26     16456
#       VulnerabilityScan       0.24      0.57      0.33     16456
#                     XSS       0.16      0.06      0.09     16456
#
#                accuracy                           0.52    568828
#               macro avg       0.50      0.51      0.47    568828
#            weighted avg       0.51      0.52      0.48    568828

# %%
start = time.time()
ab = AdaBoostClassifier(n_estimators=100, random_state=42)
ab.fit(X_train, y_train)
y_pred_ab = ab.predict(X_test)
end = time.time()

print(f"🕒 AdaBoost time: {end - start:.2f} seconds")
evaluate_model(y_test, y_pred_ab, class_names, "AdaBoost (34-class)")
# Out:
# 🕒 AdaBoost time: 1438.07 seconds
#
# 📌 Results for AdaBoost (34-class)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                          precision    recall  f1-score   support
#
#        Backdoor_Malware       0.33      0.49      0.39     16456
#           BenignTraffic       0.00      0.00      0.00     16900
#        BrowserHijacking       0.00      0.00      0.00     16456
#        CommandInjection       1.00      0.00      0.01     16456
#  DDoS-ACK_Fragmentation       1.00      0.90      0.95     16900
#         DDoS-HTTP_Flood       0.59      0.82      0.69     16456
#         DDoS-ICMP_Flood       0.00      0.00      0.00     16900
# DDoS-ICMP_Fragmentation       0.49      0.97      0.65     16900
#       DDoS-PSHACK_Flood       1.00      0.00      0.00     16900
#        DDoS-RSTFINFlood       0.99      1.00      0.99     16900
#          DDoS-SYN_Flood       0.53      0.00      0.00     16900
#          DDoS-SlowLoris       0.00      0.00      0.00     16456
# DDoS-SynonymousIP_Flood       0.94      0.98      0.96     16900
#          DDoS-TCP_Flood       0.00      0.00      0.00     16900
#          DDoS-UDP_Flood       1.00      0.97      0.98     16900
#  DDoS-UDP_Fragmentation       0.42      0.91      0.58     16900
#            DNS_Spoofing       0.54      0.38      0.45     16900
#    DictionaryBruteForce       0.09      0.84      0.16     16456
#          DoS-HTTP_Flood       0.66      0.83      0.74     16456
#           DoS-SYN_Flood       0.70      0.96      0.81     16900
#           DoS-TCP_Flood       0.23      0.93      0.37     16900
#           DoS-UDP_Flood       0.94      0.95      0.94     16900
#        MITM-ArpSpoofing       0.00      0.00      0.00     16900
#      Mirai-greeth_flood       0.33      0.00      0.00     16900
#       Mirai-greip_flood       0.50      0.99      0.66     16900
#          Mirai-udpplain       0.00      0.00      0.00     16900
#     Recon-HostDiscovery       0.00      0.00      0.00     16900
#            Recon-OSScan       0.00      0.00      0.00     16900
#         Recon-PingSweep       0.00      0.00      0.00     16456
#          Recon-PortScan       0.03      0.09      0.05     16456
#            SqlInjection       0.01      0.00      0.00     16456
#        Uploading_Attack       1.00      0.47      0.64     16456
#       VulnerabilityScan       0.00      0.00      0.00     16456
#                     XSS       1.00      0.00      0.00     16456
#
#                accuracy                           0.40    568828
#               macro avg       0.42      0.40      0.32    568828
#            weighted avg       0.42      0.40      0.33    568828

# %%
start = time.time()
perc = Perceptron(max_iter=1000, random_state=42)
perc.fit(X_train, y_train)
y_pred_perc = perc.predict(X_test)
end = time.time()

print(f"🕒 Perceptron time: {end - start:.2f} seconds")
evaluate_model(y_test, y_pred_perc, class_names, "Perceptron (34-class)")
# Out:
# 🕒 Perceptron time: 249.75 seconds
#
# 📌 Results for Perceptron (34-class)
#                          precision    recall  f1-score   support
#
#        Backdoor_Malware       0.12      0.09      0.10     16456
#           BenignTraffic       0.57      0.13      0.21     16900
#        BrowserHijacking       0.13      0.26      0.17     16456
#        CommandInjection       0.15      0.10      0.12     16456
#  DDoS-ACK_Fragmentation       0.99      0.91      0.95     16900
#         DDoS-HTTP_Flood       0.06      0.00      0.01     16456
#         DDoS-ICMP_Flood       1.00      1.00      1.00     16900
# DDoS-ICMP_Fragmentation       1.00      0.97      0.98     16900
#       DDoS-PSHACK_Flood       1.00      1.00      1.00     16900
#        DDoS-RSTFINFlood       1.00      1.00      1.00     16900
#          DDoS-SYN_Flood       0.00      0.00      0.00     16900
#          DDoS-SlowLoris       0.34      0.21      0.26     16456
# DDoS-SynonymousIP_Flood       0.96      0.06      0.11     16900
#          DDoS-TCP_Flood       0.54      0.18      0.27     16900
#          DDoS-UDP_Flood       0.58      0.95      0.72     16900
#  DDoS-UDP_Fragmentation       0.87      0.98      0.92     16900
#            DNS_Spoofing       0.15      0.06      0.09     16900
#    DictionaryBruteForce       0.39      0.18      0.25     16456
#          DoS-HTTP_Flood       0.34      0.90      0.49     16456
#           DoS-SYN_Flood       0.33      0.88      0.48     16900
#           DoS-TCP_Flood       0.50      0.83      0.63     16900
#           DoS-UDP_Flood       0.79      0.33      0.46     16900
#        MITM-ArpSpoofing       0.33      0.59      0.43     16900
#      Mirai-greeth_flood       0.66      0.05      0.09     16900
#       Mirai-greip_flood       0.50      0.95      0.66     16900
#          Mirai-udpplain       0.99      0.96      0.98     16900
#     Recon-HostDiscovery       0.32      0.50      0.39     16900
#            Recon-OSScan       0.17      0.25      0.21     16900
#         Recon-PingSweep       0.18      0.23      0.20     16456
#          Recon-PortScan       0.12      0.02      0.03     16456
#            SqlInjection       0.12      0.20      0.15     16456
#        Uploading_Attack       0.21      0.07      0.10     16456
#       VulnerabilityScan       0.38      0.46      0.42     16456
#                     XSS       0.10      0.10      0.10     16456
#
#                accuracy                           0.46    568828
#               macro avg       0.47      0.45      0.41    568828
#            weighted avg       0.47      0.46      0.41    568828

# %%
# One-hot encode labels for DNN
y_train_cat = to_categorical(y_train, num_classes=len(class_names))
y_test_cat = to_categorical(y_test, num_classes=len(class_names))

# Build DNN
model = Sequential([
    Dense(256, input_shape=(X_train.shape[1],), activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(len(class_names), activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train DNN
start = time.time()
history = model.fit(X_train, y_train_cat, epochs=20, batch_size=64, validation_split=0.1, verbose=1)
end = time.time()
print(f"🕒 DNN training time: {end - start:.2f} seconds")

# Predict and evaluate
y_pred_dnn = model.predict(X_test)
y_pred_dnn_labels = np.argmax(y_pred_dnn, axis=1)
evaluate_model(y_test, y_pred_dnn_labels, class_names, "Deep Neural Network (34-class)")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 69s 2ms/step - accuracy: 0.5928 - loss: 1.0936 - val_accuracy: 0.6792 - val_loss: 0.8510
# Epoch 2/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 64s 2ms/step - accuracy: 0.6625 - loss: 0.8969 - val_accuracy: 0.7003 - val_loss: 0.8131
# Epoch 3/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 64s 2ms/step - accuracy: 0.6702 - loss: 0.8746 - val_accuracy: 0.7017 - val_loss: 0.7931
# Epoch 4/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 64s 2ms/step - accuracy: 0.6766 - loss: 0.8625 - val_accuracy: 0.7073 - val_loss: 0.7731
# Epoch 5/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 64s 2ms/step - accuracy: 0.6806 - loss: 0.8541 - val_accuracy: 0.7021 - val_loss: 0.7855
# Epoch 6/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 64s 2ms/step - accuracy: 0.6839 - loss: 0.8479 - val_accuracy: 0.6939 - val_loss: 0.7894
# Epoch 7/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 63s 2ms/step - accuracy: 0.6853 - loss: 0.8436 - val_accuracy: 0.7094 - val_loss: 0.7826
# Epoch 8/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 64s 2ms/step - accuracy: 0.6875 - loss: 0.8390 - val_accuracy: 0.6960 - val_loss: 0.7782
# Epoch 9/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 64s 2ms/step - accuracy: 0.6884 - loss: 0.8372 - val_accuracy: 0.7014 - val_loss: 0.7726
# Epoch 10/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 64s 2ms/step - accuracy: 0.6886 - loss: 0.8362 - val_accuracy: 0.7236 - val_loss: 0.7486
# Epoch 11/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 63s 2ms/step - accuracy: 0.6922 - loss: 0.8312 - val_accuracy: 0.7139 - val_loss: 0.7706
# Epoch 12/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 64s 2ms/step - accuracy: 0.6882 - loss: 0.8350 - val_accuracy: 0.7183 - val_loss: 0.7592
# Epoch 13/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 64s 2ms/step - accuracy: 0.6948 - loss: 0.8368 - val_accuracy: 0.7180 - val_loss: 0.7563
# Epoch 14/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 63s 2ms/step - accuracy: 0.6931 - loss: 0.8280 - val_accuracy: 0.7250 - val_loss: 0.7476
# Epoch 15/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 65s 2ms/step - accuracy: 0.6967 - loss: 0.8241 - val_accuracy: 0.6955 - val_loss: 0.7641
# Epoch 16/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 64s 2ms/step - accuracy: 0.6955 - loss: 0.8263 - val_accuracy: 0.7296 - val_loss: 0.7357
# Epoch 17/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 64s 2ms/step - accuracy: 0.6958 - loss: 0.8255 - val_accuracy: 0.7274 - val_loss: 0.7368
# Epoch 18/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 64s 2ms/step - accuracy: 0.6982 - loss: 0.8201 - val_accuracy: 0.7228 - val_loss: 0.7375
# Epoch 19/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 64s 2ms/step - accuracy: 0.6982 - loss: 0.8198 - val_accuracy: 0.7141 - val_loss: 0.7497
# Epoch 20/20
# 31997/31997 ━━━━━━━━━━━━━━━━━━━━ 65s 2ms/step - accuracy: 0.6976 - loss: 0.8210 - val_accuracy: 0.7233 - val_loss: 0.7420
# 🕒 DNN training time: 1284.02 seconds
# 17776/17776 ━━━━━━━━━━━━━━━━━━━━ 20s 1ms/step
#
# 📌 Results for Deep Neural Network (34-class)
#                          precision    recall  f1-score   support
#
#        Backdoor_Malware       0.51      0.44      0.47     16456
#           BenignTraffic       0.65      0.70      0.68     16900
#        BrowserHijacking       0.49      0.66      0.56     16456
#        CommandInjection       0.66      0.28      0.40     16456
#  DDoS-ACK_Fragmentation       1.00      0.98      0.99     16900
#         DDoS-HTTP_Flood       0.86      0.91      0.89     16456
#         DDoS-ICMP_Flood       1.00      1.00      1.00     16900
# DDoS-ICMP_Fragmentation       0.99      0.98      0.99     16900
#       DDoS-PSHACK_Flood       1.00      1.00      1.00     16900
#        DDoS-RSTFINFlood       1.00      1.00      1.00     16900
#          DDoS-SYN_Flood       0.57      0.93      0.71     16900
#          DDoS-SlowLoris       0.93      0.97      0.95     16456
# DDoS-SynonymousIP_Flood       0.79      0.71      0.75     16900
#          DDoS-TCP_Flood       0.58      0.99      0.73     16900
#          DDoS-UDP_Flood       0.78      0.79      0.79     16900
#  DDoS-UDP_Fragmentation       1.00      0.99      0.99     16900
#            DNS_Spoofing       0.67      0.49      0.57     16900
#    DictionaryBruteForce       0.57      0.51      0.54     16456
#          DoS-HTTP_Flood       0.91      0.84      0.88     16456
#           DoS-SYN_Flood       0.84      0.38      0.52     16900
#           DoS-TCP_Flood       0.95      0.28      0.43     16900
#           DoS-UDP_Flood       0.79      0.78      0.78     16900
#        MITM-ArpSpoofing       0.91      0.53      0.67     16900
#      Mirai-greeth_flood       0.95      0.84      0.89     16900
#       Mirai-greip_flood       0.86      0.95      0.90     16900
#          Mirai-udpplain       1.00      0.99      1.00     16900
#     Recon-HostDiscovery       0.78      0.64      0.70     16900
#            Recon-OSScan       0.56      0.28      0.37     16900
#         Recon-PingSweep       0.47      0.83      0.60     16456
#          Recon-PortScan       0.53      0.33      0.40     16456
#            SqlInjection       0.48      0.62      0.54     16456
#        Uploading_Attack       0.32      0.79      0.45     16456
#       VulnerabilityScan       0.94      0.98      0.96     16456
#                     XSS       0.33      0.22      0.26     16456
#
#                accuracy                           0.72    568828
#               macro avg       0.75      0.72      0.72    568828
#            weighted avg       0.76      0.72      0.72    568828
